# %% [markdown]
# Write program to implement point/pixel intensity transformations
# such as
#
#     -Log and Power-law transformations
#     -Contrast adjustments
#     -Histogram equalization
#     -Thresholding, and halftoning operations

# %%
#import libraries
import cv2
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
# Open the image.
img = cv2.imread('lenna.jpg')

# %%
# Apply log transform.
c = 255/(np.log(1 + np.max(img)))
log_transformed = c * np.log(1 + img)
# Out:
# /tmp/ipykernel_7487/507405972.py:3: RuntimeWarning: divide by zero encountered in log
#   log_transformed = c * np.log(1 + img)

# %%
# Specify the data type.
log_transformed = np.array(log_transformed, dtype = np.uint8)
# Save the output.
cv2.imwrite('log_transformed.jpg', log_transformed)
# Out:
# True

# %%
img = mpimg.imread('log_transformed.jpg')  #show saved image (log transformed)
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
#     -Power law transform

# %%
img = cv2.imread('lenna_original.jpg')
  
# Trying 4 gamma values.
for gamma in [0.1, 0.5, 1.2, 2.2]:
      
    # Apply gamma correction.
    gamma_corrected = np.array(255*(img / 255) ** gamma, dtype = 'uint8')
  
    # Save edited images.
    cv2.imwrite('gamma_transformed'+str(gamma)+'.jpg', gamma_corrected)

# %%
#code to show different gamma levels in power law transform
for i in [0.1, 0.5, 1.2, 2.2]:
    img = mpimg.imread(f'gamma_transformed'+str(i)+'.jpg') 
    imgplot = plt.imshow(img)
    plt.show()
